// %% [markdown]
// **Disclaimer:**
//
// 1. C# question results were aided by the Week1 and Week2 Notebooks, as well as the debugging messages in Visual Studio<br>
// 2. Python question results were aided by the Week3 Notebooks, and were completed in IDLE

// %% [markdown]
// # Question 1 C*sharp*
//
// What data type is each of the following?

// %% [markdown]
// | Test | Description |
// |:---|:---|
// | 5 = int | (whole numeric) |
// | 5.0 = float | (numeric with one decimal place) |
// | 5 > 1 = bool | (the variable would store a boolean value of True) |
// | '5' = int | (the variable stores the ascii value of 5, which is 53, which is a whole number) |
// | 5 * 2 = int | (the variable stores the result of 5 times 2, which is 10, which is a whole number) |
// | '5' * 2 = int | (the variable stores the result of the ascii value of 5 times 2, which is 53 times 2 = 106, a whole number) |
// | '5' + '2' = int | (the variable stores the result of the ascii value of 5 plus the ascii value of 2, which is 53 + 50 = 103, a whole number |
// | 5 / 2 = float | (the variable stores 5 divided by 2 = 2.5, numeric with one decimal place) |
// | 5 % 2 = int | (the variable stores a whole number of 1 because there is a remainder of 1 left after dividing 5 by 2) |
// | {5, 2, 1} = int[] | (the variable stores a single-dimensional array) |
// | 5 == 3 = bool | (the variable stores a boolean value of False) |
// | Pi (the number) = double | (the variable stores the value of PI as a numeric with 15 decimal places) |

// %% [markdown]
// # Question 2 C*sharp*
//
// Write (and evaluate) C\# expressions that answer these questions:
//
// **Part a.**
//
// How many letters are there in 'Supercalifragilisticexpialidocious'?

// %%
string word = "Supercalifragilisticexpialidocious";
int wordlength = (int)word.Length;
Console.WriteLine($"The length of {word} is {wordlength} characters");
// Out:
// The length of Supercalifragilisticexpialidocious is 34 characters

// %% [markdown]
// **Part b.**
//
// Does 'Supercalifragilisticexpialidocious' contain 'ice' as a substring?

// %%
string word = "Supercalifragilisticexpialidocious";
bool sub = word.Contains("ice");
Console.WriteLine($"{word} contains ice: {sub}");
// Out:
// Supercalifragilisticexpialidocious contains ice: True

// %% [markdown]
// **Part c.**
//
// Which of the following words is the longest:
// Supercalifragilisticexpialidocious, Honorificabilitudinitatibus, or
// Bababadalgharaghtakamminarronnkonn?

// %%
string word1 = "Supercalifragilisticexpialidocious";
int word1len = (int)word1.Length;
Console.WriteLine($"{word1} has {word1len} characters");
string word2 = "Honorificabilitudinitatibus";
int word2len = (int)word2.Length;
Console.WriteLine($"{word2} has {word2len} characters");
string word3 = "Bababadalgharaghtakamminarronnkonn";
int word3len = (int)word3.Length;
Console.WriteLine($"{word3} has {word3len} characters");
int[] wordslen = new int[3];
wordslen[0] = word1len;
wordslen[1] = word2len;
wordslen[2] = word3len;
int longest = wordslen.Max();
Console.WriteLine($"The longest word(s) have {longest} characters");
// Out:
// Supercalifragilisticexpialidocious has 34 characters
// Honorificabilitudinitatibus has 27 characters
// Bababadalgharaghtakamminarronnkonn has 34 characters
// The longest word(s) have 34 characters

// %% [markdown]
// **Part d.**
//
// Which composer comes first in the dictionary: 'Berlioz', 'Borodin', 'Brian',
// 'Bartok', 'Bellini', 'Buxtehude', 'Bernstein'? Which comes last?

// %%
var names = new List<string>();
names.Add("Berlioz");
names.Add("Borodin");
names.Add("Brian");
names.Add("Bartok");
names.Add("Bellini");
names.Add("Buxtehude");
names.Add("Bernstein");
string first = names.Min();
Console.WriteLine($"The first name in the list is {first}.");
string last = names.Max();
Console.WriteLine($"The last name in the list is {last}.");
// Out:
// The first name in the list is Bartok.
// The last name in the list is Buxtehude.

// %% [markdown]
// # Question 3 C*sharp*
//
// Implement function triangleArea(a,b,c) that takes as input the lengths of the 3 sides of a triangle and returns the area of the triangle. By Heron's formula, the area of a triangle with side lengths a, b, and c is square root of (s(s-a)(s-b)(s-c)), where s = (a+b+c)/2

// %%
// Visual Studio Syntax
namespace WorkingQuestions345.Model
{
    class Herons
    {
        //Ask for user input
        
        static void triangleArea(int side1, int side2, int side3)
        {
            double s1 = (side1 + side2 + side3)/2;

            double s2 = s1 * (s1 - side1) * (s1 - side2) * (s1 - side3);

            double s3 = Math.Sqrt(s2);
            Console.WriteLine($"The area of the triangle is {s3}");
        }
    }
}

using WorkingQuestions345.Model;

Herons cal = new Herons();
cal.triangleArea(2,2,2);

// %%
int side1 = 2; int side2 = 2; int side3 = 2; 
    double s1 = (side1 + side2 + side3)/2;
    double s2 = s1 * (s1 - side1) * (s1 - side2) * (s1 - side3);
    double s3 = Math.Sqrt(s2);
    Console.WriteLine($"The area of the triangle is {s3}");
// Out:
// The area of the triangle is 1.7320508075688772

// %% [markdown]
// # Question 4 C*sharp*
//
// Write a program in C# to separate odd and even integers in separate arrays.

// %%
int[] all = new int[5];
all[0] = 25;
all[1] = 47;
all[2] = 42;
all[3] = 56;
all[4] = 32;

var even = new List<int>();
var odd = new List<int>();

foreach (int n in all)
{
    if (n % 2 == 0)
    {
        even.Add(n);
    }
    else
    {
        odd.Add(n);
    }
}

Console.WriteLine("The even numbers are:");
foreach (int num in even)
{
    Console.Write($"{num} ");
}
Console.WriteLine("\nThe odd numbers are:");
foreach (int num in odd)
{
    Console.Write($"{num} ");
}
// Out:
// The even numbers are:
// 42 56 32
// The odd numbers are:
// 25 47

// %% [markdown]
// # Question 5 C*sharp*
//
// **Part a.**
//
// Write a function inside(x,y,x1,y1,x2,y2) that returns True or False depending on whether the point (x,y) lies in the rectangle with lower left corner (x1,y1) and upper right corner (x2,y2).

// %%
//Visual Studio Syntax
namespace WorkingQuestion5.Model
{
    internal class rectangle
    {
        int x, y, x1, y1, x2, y2; //x,y is the point to locate, x1,y1 is the lower left of the rect, x2,y2 is the upper right
        public void inside(int x,int y)
        {
            int[,] coords = new int[3, 2] { { x, y }, { 0, 0 }, { 2, 3 } };
            x = coords[0, 0];
            y = coords[0, 1];
            x1 = coords[1, 0];
            y1 = coords[1, 1];
            x2 = coords[2, 0];
            y2 = coords[2, 1];
            if (x > x1 && x < x2)
            {
                if (y > y1 && y < y2)
                {
                    Console.WriteLine("The point falls within the rectangle");
                }
                else
                {
                    Console.WriteLine("The point is outside of the rectangle");
                }
            }
            else
            {
                Console.WriteLine("The point is outside the rectangle");
            }
        }

    }
}

using WorkingQuestion5.Model;

rectangle point = new rectangle();

point.inside(1, 1);
point.inside(-1, -1);
// Out:
// (2,1): error CS7021: Cannot declare namespace in script code
// (36,1): error CS1529: A using clause must precede all other elements defined in the namespace except extern alias declarations

// %%
//modify values of x, y to test if point falls within the rectangle
int x = -1; int y = -1; int x1; int y1; int x2; int y2;
int[,] coords = new int[3, 2] { { x, y }, { 0, 0 }, { 2, 3 } };
            x = coords[0, 0];
            y = coords[0, 1];
            x1 = coords[1, 0];
            y1 = coords[1, 1];
            x2 = coords[2, 0];
            y2 = coords[2, 1];
            if (x > x1 && x < x2)
            {
                if (y > y1 && y < y2)
                {
                    Console.WriteLine("The point falls within the rectangle");
                }
                else
                {
                    Console.WriteLine("The point is outside of the rectangle");
                }
            }
            else
            {
                Console.WriteLine("The point is outside the rectangle");
            }
// Out:
// The point is outside the rectangle

// %% [markdown]
// **Part b.**
//
// Use function inside() from part a. to write an expression that tests whether the point (1,1) lies in both of the following rectangles: one with lower left corner (0.3,0.5) and upper right corner (1.1,0.7) and the other with lower left corner (0.5,0.2) and upper right corner (1.1,2).

// %%
//Visual Studio Syntax
namespace WorkingQuestion5.Model
{
    internal class rectangle
    {
        double x, y, x1, y1, x2, y2, x3, y3, x4, y4; //x,y is the point to locate, x1,y1 is the lower left of the rect, x2,y2 is the upper right
        public void inside(double x,double y)
        {
            double[,] coords = new double[5, 2] { { x, y }, { 0.3, 0.5 }, { 1.1, 0.7 }, { 0.5, 0.2 }, { 1.1, 2 } };
            x = coords[0, 0];
            y = coords[0, 1];
            x1 = coords[1, 0];
            y1 = coords[1, 1];
            x2 = coords[2, 0];
            y2 = coords[2, 1];
            x3 = coords[3, 0];
            y3 = coords[3, 1];
            x4 = coords[4, 0];
            y4 = coords[4, 1];
            if (x > x1 && x < x2)
            {
                if (y > y1 && y < y2)
                {
                    if (x > x3 && x < x4)
                    {
                        if (y > y3 && y < y4)
                        {
                            Console.WriteLine("Yes, the point is within BOTH rectangles");
                        }
                        else
                        {
                            Console.WriteLine("The point is outside of the rectangle");
                        }
                    }
                    else
                    {
                        Console.WriteLine("The point is outside of the rectangle");
                    }
                }
                else
                {
                    Console.WriteLine("The point is outside of the rectangle");
                }
            }
            else
            {
                Console.WriteLine("The point is outside the rectangle");
            }
        }

    }
}

using WorkingQuestion5.Model;

rectangle point = new rectangle();

point.inside(1, 0.6);

// %%
//modify the value of x, y to test a new point
double x = 1; double y = 0.6; double x1; double y1; double x2; double y2; double x3; double y3; double x4; double y4;
double[,] coords = new double[5, 2] { { x, y }, { 0.3, 0.5 }, { 1.1, 0.7 }, { 0.5, 0.2 }, { 1.1, 2 } };
            x = coords[0, 0];
            y = coords[0, 1];
            x1 = coords[1, 0];
            y1 = coords[1, 1];
            x2 = coords[2, 0];
            y2 = coords[2, 1];
            x3 = coords[3, 0];
            y3 = coords[3, 1];
            x4 = coords[4, 0];
            y4 = coords[4, 1];
            if (x > x1 && x < x2)
            {
                if (y > y1 && y < y2)
                {
                    if (x > x3 && x < x4)
                    {
                        if (y > y3 && y < y4)
                        {
                            Console.WriteLine("Yes, the point is within BOTH rectangles");
                        }
                        else
                        {
                            Console.WriteLine("The point is outside of the rectangle");
                        }
                    }
                    else
                    {
                        Console.WriteLine("The point is outside of the rectangle");
                    }
                }
                else
                {
                    Console.WriteLine("The point is outside of the rectangle");
                }
            }
            else
            {
                Console.WriteLine("The point is outside the rectangle");
            }
// Out:
// Yes, the point is within BOTH rectangles

// %% [markdown]
// # Question 6 Python
//
// You can turn a word into pig-Latin using the following two rules (simplified):
//     1. If the word starts with a consonant, move that letter to the end and append 'ay'. For example, 'happy' becomes 'appyhay' and 'pencil' becomes 'encilpay'.
//     2. If the word starts with a vowel, simply append 'way' to the end of the word. For example, 'enter' becomes 'enterway' and 'other' becomes 'otherway'. For our purposes, there are 5 vowels: a, e, i, o, u (so we count y as a consonant).
//
// Write a function pig() that takes a word (i.e., a string) as input and returns its pig-Latin form. Your function should still work if the input word contains upper case characters. Your output should always be lower case however.

// %%
//Python 3 syntax
def pig(word):
    word = word.lower()
    if word[0] in ('a', 'e', 'i', 'o' 'u'):
        print(word+'way')
    else:
        print(word[1:]+word[0]+'ay')

pig('Robyn')
pig('Ethan')

// %% [markdown]
// ![Question6_ScreenShot-3.jpg](attachment:Question6_ScreenShot-3.jpg)

// %% [markdown]
// # Question 7 Python
//
// File bloodtype2.txt records blood-types of patients (A, B, AB, O or OO) at a clinic. Write a function bldcount() that reads the file with name *name* and reports (i.e. prints) how many patients there are in each bloodtype.

// %%
//Python 3 syntax
def bldcount(name):
    infile = open(name,'r')
    types = (infile.read())
    lst = types.split(" ")

    A = lst.count('A')
    print('There are',A,'patients with blood type A.')
    B = lst.count('B')
    print('There is',B,'patient with blood type B.')
    AB = lst.count('AB')
    print('There are',AB,'patients with blood type AB.')
    O = lst.count('O')
    print('There are',O,'patients with blood type O.')
    OO = lst.count('OO')
    print('There are',OO,'patients with blood type OO.')
            

bldcount('bloodtype1.txt')

// %% [markdown]
// ![Question7_ScreenShot-3.jpg](attachment:Question7_ScreenShot-3.jpg)

// %% [markdown]
// # Question 8 Python
//
// Write a function curconv() that takes as input:
// 1. a currency represented using a string (e.g. 'JPY' for the Japanese Yen or 'EUR' for the Euro)
// 2. an amount
//
// and then converts and returns the amount in US dollars

// %%
//Python 3 syntax
print('This program will convert your currency into USD')
print('The currency types to choose from are: AUD, CHF, CNY, DKK, EUR,')
print('GBP, HKD, INR, JPY, MXN, MYR, NOK, NZD, PHP, SEK, SGD, THB')
print('')

currencytype = input('Please enter a currency type: ')
dollaramount = eval(input('Please enter a dollar amount: '))
print('')

def curconv(curtype, amount):
    infile = open('currencies.txt', 'r')
    conversion = (infile.read())
    lst = conversion.split('\n')
    for i in lst:
        sublst = i.split('\t')
        if sublst[0] == curtype:
            x = float(sublst[1])
            conv = x * amount
            print(amount,curtype,'=',conv,'USD')
            break

curconv(currencytype, dollaramount)

// %% [markdown]
// ![Question8_ScreenShot-2.jpg](attachment:Question8_ScreenShot-2.jpg)

// %% [markdown]
// # Question 9 Python
//
// Each of the following will cause an exception (an error). Identify what type of exception each will cause.

// %% [markdown]
// Trying to add incompatible variables, as in adding 6 + 'a'
// >Type Error is given because the datatypes don't match
//
// Referring to the 12th item of a list that has only 10 items
// >Index Error is given because the item is out of range of the list length
//
// Using a value that is out of range for a function's input, such as calling math.sqrt(-1.0)
// >Value Error is given because the sqrt function requires a positive number
//
// Using an undeclared variable, such as print(x) when x has not been defined
// >Name Error is given because the x variable has no value assigned to it
//
// Trying to open a file that does not exist, such as mistyping the file name or looking in the wrong directory
// >File Not Found Error is given because there is no such file or directory matching the input

// %% [markdown]
// # Question 10 Python
//
// Encryption is the process of hiding the meaning of a text by substituting letters in the message with other letters, according to some system. If the process is successful, no one but the intended recipient can understand the encrypted message. Cryptanalysis referes to attempts to undo the encryption, even if some details of the encryption are unknown (for example, if an encrypted message has been intercepted). The first step of cryptanalysis is often to build up a table of letter frequencies in the encrypted text. Assume that the string letters is already defined as 'abcdefghijklmnopqrstuvwxyz'. Write a function called frequencies() that takes a string as its only parameter, and returns a list of integers, showing the number of times each character appears in the text. Your function may ignore any characters that are not in letters.

// %%
//Python 3 syntax
def frequencies(word):
    letters = 'abcdefghijklmnopqrstuvwxyz'
    lst = []
    wlst = []
    clst = []
    for w in word:
        wlst.append(w)
    for l in letters:
        lst.append(l)
    for n in lst:   #returns a from letters
        if n in wlst:  #a is in wlst
            x = wlst.count(n)
            clst.append(x)
        else:
            clst.append(0)
            
    print('The encryption of',word,'is: ')
    print(clst)
    print('')

frequencies('The quick red fox got bored and went home.')
frequencies('apple')

// %% [markdown]
// ![Question10_ScreenShot-2.jpg](attachment:Question10_ScreenShot-2.jpg)
